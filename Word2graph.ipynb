# %%
from graph_of_words import GraphOfWords
# t= "Cecilia Love, 52, a retired police investigator who lives in Massachusetts, said she paid around $370 a ticket with tax for nonstop United Airlines flights to Sacramento from Boston for her niece's high school graduation in June, 2020."
text = "Elizabeth, I need to update several of our faculty and teaching staff on the changes in the English department’s process for assigning teaching schedules to Graduate Teaching Assistants. As you know, the old process gave preference to more senior TAs, which led to numerous complaints of unfairness and an overall lack of clarity. Starting next semester, the English department will transition to a new rolling system that divides TAs into four groups alphabetically and ensures each group will be given first preference of teaching times once every two academic years. This change will go into effect starting January 5, 2015. In your message I would like you to outline the new process and explain the reasons why we need to make this change. Please provide contact information for the assistant department head in case anyone needs further information. Oh, and this information will also need to be copied to the appropriate associate dean. I appreciate your help with this."

# graph = GraphOfWords(window_size=2)
# graph.build_graph(
#     text,
#     # OR a sentences list['Roses  are  red.', 'Violets are blue'],
#     remove_stopwords=False,
#     workers=4
# )

# graph.display_graph()
# # graph.write_graph_edges('edges_list.txt')

# %%
# SPDX-FileCopyrightText: 2019 Vincent Lequertier <vi.le@autistici.org>
# SPDX-License-Identifier: GPL-3.0-only
import spacy
nlp = spacy.load('en_core_web_lg')
from allennlp.predictors.predictor import Predictor

model_url = 'https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2020.02.27.tar.gz'
predictor = Predictor.from_path(model_url)


def get_sen_structure(doc):
    structure = {}
    for token in nlp(doc):
        ancestors = [t.text for t in token.ancestors]
        children = [t.text for t in token.children]
        structure[token.i] = {"text" : token.text,"pos":token.pos_,"dep":token.dep_,"head":token.head.text,"children":children,"ancestors":ancestors}
                              # "children":children,"ancestors":ancestors}
        # print(token.text, "\t", token.i, "\t", 
        #       token.pos_, "\t", token.dep_, "\t", 
        #       ancestors, "\t", children)
        # print(token.text,"\t", token.pos_,"\t", token.head.text, "\t", token.dep_, "\t", 
        #        children)
              # ," \t",ancestors)
    return structure
# Out:
# /home/hadeer/PycharmProjects/Graph/venv/lib/python3.8/site-packages/allennlp/tango/__init__.py:17: UserWarning: AllenNLP Tango is an experimental API and parts of it might change or disappear every time we release a new version.
#   warnings.warn(
# 2021-11-16 12:58:04,284 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2021-11-16 12:58:04,479 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2020.02.27.tar.gz is up-to-date
# 2021-11-16 12:58:04,481 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2020.02.27.tar.gz from cache at /home/hadeer/.allennlp/cache/0f6b052811b20b13280e609a96efe71ebc636b9c823a5c906ba24459e6e68af9.c1dab61d84cc7c3f7d6751c260040607cb7023a002778ba8f9b9d196b6539174
# 2021-11-16 12:58:04,483 - INFO - allennlp.models.archival - extracting archive file /home/hadeer/.allennlp/cache/0f6b052811b20b13280e609a96efe71ebc636b9c823a5c906ba24459e6e68af9.c1dab61d84cc7c3f7d6751c260040607cb7023a002778ba8f9b9d196b6539174 to temp dir /tmp/tmpz8z7udvr
# 2021-11-16 12:58:14,637 - INFO - allennlp.common.params - dataset_reader.type = coref
# 2021-11-16 12:58:14,638 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2021-11-16 12:58:14,638 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2021-11-16 12:58:14,639 - INFO - allennlp.common.params - dataset_reader.manual_multiprocess_sharding = False
# 2021-11-16 12:58:14,639 - INFO - allennlp.common.params - dataset_reader.max_span_width = 30
# 2021-11-16 12:58:14,639 - INFO - allennlp.common.params - dataset_reader.token_indexers.type = ref
# 2021-11-16 12:58:14,643 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-11-16 12:58:14,644 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-11-16 12:58:14,644 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-11-16 12:58:14,644 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.model_name = SpanBERT/spanbert-large-cased
# 2021-11-16 12:58:14,645 - INFO - allennlp.common.params - type = SpanBERT/spanbert-large-cased
# 2021-11-16 12:58:14,645 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.namespace = tags
# 2021-11-16 12:58:14,645 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.max_length = 512
# 2021-11-16 12:58:14,646 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.tokenizer_kwargs = None
# 2021-11-16 12:58:22,924 - INFO - allennlp.common.params - dataset_reader.wordpiece_modeling_tokenizer = None
# 2021-11-16 12:58:22,925 - INFO - allennlp.common.params - dataset_reader.max_sentences = 110
# 2021-11-16 12:58:22,925 - INFO - allennlp.common.params - dataset_reader.remove_singleton_clusters = False
# 2021-11-16 12:58:22,926 - INFO - allennlp.common.params - validation_dataset_reader.type = coref
# 2021-11-16 12:58:22,926 - INFO - allennlp.common.params - validation_dataset_reader.max_instances = None
# 2021-11-16 12:58:22,926 - INFO - allennlp.common.params - validation_dataset_reader.manual_distributed_sharding = False
# 2021-11-16 12:58:22,927 - INFO - allennlp.common.params - validation_dataset_reader.manual_multiprocess_sharding = False
# 2021-11-16 12:58:22,927 - INFO - allennlp.common.params - validation_dataset_reader.max_span_width = 30
# 2021-11-16 12:58:22,927 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.type = ref
# 2021-11-16 12:58:22,928 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-11-16 12:58:22,929 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-11-16 12:58:22,929 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-11-16 12:58:22,929 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.model_name = SpanBERT/spanbert-large-cased
# 2021-11-16 12:58:22,930 - INFO - allennlp.common.params - type = SpanBERT/spanbert-large-cased
# 2021-11-16 12:58:22,930 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.namespace = tags
# 2021-11-16 12:58:22,930 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.max_length = 512
# 2021-11-16 12:58:22,931 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.tokenizer_kwargs = None
# 2021-11-16 12:58:22,933 - INFO - allennlp.common.params - validation_dataset_reader.wordpiece_modeling_tokenizer = None
# 2021-11-16 12:58:22,934 - INFO - allennlp.common.params - validation_dataset_reader.max_sentences = None
# 2021-11-16 12:58:22,934 - INFO - allennlp.common.params - validation_dataset_reader.remove_singleton_clusters = False
# 2021-11-16 12:58:22,935 - INFO - allennlp.common.params - type = from_instances
# 2021-11-16 12:58:22,935 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmpz8z7udvr/vocabulary.
# 2021-11-16 12:58:22,937 - INFO - allennlp.common.params - model.type = coref
# 2021-11-16 12:58:22,937 - INFO - allennlp.common.params - model.regularizer = None
# 2021-11-16 12:58:22,938 - INFO - allennlp.common.params - model.ddp_accelerator = None
# 2021-11-16 12:58:22,938 - INFO - allennlp.common.params - model.text_field_embedder.type = ref
# 2021-11-16 12:58:22,940 - INFO - allennlp.common.params - model.text_field_embedder.type = basic
# 2021-11-16 12:58:22,941 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.type = ref
# 2021-11-16 12:58:22,942 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2021-11-16 12:58:22,943 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2021-11-16 12:58:22,944 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.model_name = SpanBERT/spanbert-large-cased
# 2021-11-16 12:58:22,944 - INFO - allennlp.common.params - type = SpanBERT/spanbert-large-cased
# 2021-11-16 12:58:22,944 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.max_length = 512
# 2021-11-16 12:58:22,945 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.train_parameters = True
# 2021-11-16 12:58:22,945 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.last_layer_only = True
# 2021-11-16 12:58:22,946 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.override_weights_file = None
# 2021-11-16 12:58:22,946 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.override_weights_strip_prefix = None
# 2021-11-16 12:58:22,947 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.load_weights = True
# 2021-11-16 12:58:22,947 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.gradient_checkpointing = None
# 2021-11-16 12:58:22,947 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.tokenizer_kwargs = None
# 2021-11-16 12:58:22,948 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.transformer_kwargs = None
# 2021-11-16 12:58:22,948 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.sub_token_mode = avg
# Some weights of BertModel were not initialized from the model checkpoint at SpanBERT/spanbert-large-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2021-11-16 12:58:26,534 - INFO - allennlp.common.params - model.context_layer.type = pass_through
# 2021-11-16 12:58:26,535 - INFO - allennlp.common.params - model.context_layer.type = pass_through
# 2021-11-16 12:58:26,535 - INFO - allennlp.common.params - model.context_layer.input_dim = 1024
# 2021-11-16 12:58:26,536 - INFO - allennlp.common.params - model.mention_feedforward.type = ref
# 2021-11-16 12:58:26,537 - INFO - allennlp.common.params - model.mention_feedforward.input_dim = 3092
# 2021-11-16 12:58:26,537 - INFO - allennlp.common.params - model.mention_feedforward.num_layers = 2
# 2021-11-16 12:58:26,538 - INFO - allennlp.common.params - model.mention_feedforward.hidden_dims = 1500
# 2021-11-16 12:58:26,538 - INFO - allennlp.common.params - model.mention_feedforward.activations = relu
# 2021-11-16 12:58:26,539 - INFO - allennlp.common.params - type = relu
# 2021-11-16 12:58:26,539 - INFO - allennlp.common.params - type = relu
# 2021-11-16 12:58:26,539 - INFO - allennlp.common.params - type = relu
# 2021-11-16 12:58:26,540 - INFO - allennlp.common.params - model.mention_feedforward.dropout = 0.3
# 2021-11-16 12:58:26,587 - INFO - allennlp.common.params - model.antecedent_feedforward.type = ref
# 2021-11-16 12:58:26,588 - INFO - allennlp.common.params - model.antecedent_feedforward.input_dim = 9296
# 2021-11-16 12:58:26,589 - INFO - allennlp.common.params - model.antecedent_feedforward.num_layers = 2
# 2021-11-16 12:58:26,589 - INFO - allennlp.common.params - model.antecedent_feedforward.hidden_dims = 1500
# 2021-11-16 12:58:26,590 - INFO - allennlp.common.params - model.antecedent_feedforward.activations = relu
# 2021-11-16 12:58:26,590 - INFO - allennlp.common.params - type = relu
# 2021-11-16 12:58:26,590 - INFO - allennlp.common.params - type = relu
# 2021-11-16 12:58:26,591 - INFO - allennlp.common.params - type = relu
# 2021-11-16 12:58:26,591 - INFO - allennlp.common.params - model.antecedent_feedforward.dropout = 0.3
# 2021-11-16 12:58:26,695 - INFO - allennlp.common.params - model.feature_size = 20
# 2021-11-16 12:58:26,695 - INFO - allennlp.common.params - model.max_span_width = 30
- INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.bias
# 2021-11-16 12:58:26,898 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.weight
# 2021-11-16 12:58:26,899 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2021-11-16 12:58:26,899 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2021-11-16 12:58:26,899 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2021-11-16 12:58:26,899 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2021-11-16 12:58:26,899 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.bias
# 2021-11-16 12:58:26,900 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.weight
# 2021-11-16 12:58:26,900 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.bias
# 2021-11-16 12:58:26,900 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.weight
# 2021-11-16 12:58:26,906 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2021-11-16 12:58:26,906 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2021-11-16 12:58:28,909 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmpz8z7udvr

# %%
import networkx as nx

# %%
def get_sentences(text):
    Sentences = [str(i).lstrip().lower()for i in list(nlp(predictor.coref_resolved(text)).sents)]
    return Sentences

# %%
text
# Out:
# 'Elizabeth, I need to update several of our faculty and teaching staff on the changes in the English department’s process for assigning teaching schedules to Graduate Teaching Assistants. As you know, the old process gave preference to more senior TAs, which led to numerous complaints of unfairness and an overall lack of clarity. Starting next semester, the English department will transition to a new rolling system that divides TAs into four groups alphabetically and ensures each group will be given first preference of teaching times once every two academic years. This change will go into effect starting January 5, 2015. In your message I would like you to outline the new process and explain the reasons why we need to make this change. Please provide contact information for the assistant department head in case anyone needs further information. Oh, and this information will also need to be copied to the appropriate associate dean. I appreciate your help with this.'

# %%
Sentences = get_sentences(text)
# [str(i).lstrip().lower()for i in list(nlp((text)).sents)]
def create_graph(Sentences):
    attr_graph = nx.MultiDiGraph()
    for i in Sentences:#[1:2]:
        All_info = get_sen_structure(i)
        # Add Nodes
        for key in All_info:
            attr_graph.add_node(All_info[key]['text'],pos=All_info[key]['pos'])
        # ADD EDGES
        for key in All_info:
            attr_graph.add_edge(All_info[key]['head'],All_info[key]['text'], label = All_info[key]['dep'])
    return attr_graph

# %%
attr_graph = create_graph(Sentences)

# %%
from pyvis import network as pvnet

def plot_g_pyviz(G, name='out.html', height='300px', width='500px'):
    g = G.copy() # some attributes added to nodes
    net = pvnet.Network(notebook=True, directed=True, height=height, width=width)
    opts = '''
        var options = {
          "physics": {
            "forceAtlas2Based": {
              "gravitationalConstant": -100,
              "centralGravity": 0.11,
              "springLength": 100,
              "springConstant": 0.09,
              "avoidOverlap": 1
            },
            "minVelocity": 0.75,
            "solver": "forceAtlas2Based",
            "timestep": 0.22
          }
          
        }
    '''

    net.set_options(opts)
    # uncomment this to play with layout
    # net.show_buttons(filter_=['physics'])
    # net.enable_physics(True)
    net.from_nx(g)
    return net.show(name)

# %%
plot_g_pyviz(attr_graph)
# Out:
#         <iframe
#             width="500px"
#             height="300px"
#             src="out.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import os
def get_graph_dict(graph):
    return nx.to_dict_of_dicts(graph)
def save_graph_pickle(graph):
    return nx.write_gpickle(graph,"word2graph.gpickle")
def load_graph_pickle(path):
    return nx.read_gpickle(path)
